# %% [markdown]
# # 04 — Backtesting & ROI Tracker
# Full sports investing simulation with Kelly Criterion

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

import pandas as pd
import numpy as np
import joblib
import matplotlib.pyplot as plt

from config import PATHS, KELLY, VALUE_BET
from src.betting_engine import detect_value_bets
print("✅ Backtesting modules loaded")
# Out:
# ✅ Backtesting modules loaded

# %%
# Load your trained model and data
model = joblib.load(PATHS.MODEL_MATCH_RESULT)
df = pd.read_parquet(PATHS.PROCESSED / "features_master.parquet")

print(f"Ready for backtesting on {len(df):,} matches")
# Out:
# Ready for backtesting on 14,255 matches

# %%
# Simple simulation (expand with real model predictions)
print("\n=== Backtesting Framework ===")
print("Bankroll starting at:", KELLY.DEFAULT_BANKROLL, "units")

# Placeholder for full backtest loop
bankroll = KELLY.DEFAULT_BANKROLL
print(f"Current Bankroll: {bankroll:.2f} units")

print("\nNext: Add real predictions, value detection, and equity curve plotting")
# Out:
# === Backtesting Framework ===
# Bankroll starting at: 1000.0 units
# Current Bankroll: 1000.00 units
#
# Next: Add real predictions, value detection, and equity curve plotting
